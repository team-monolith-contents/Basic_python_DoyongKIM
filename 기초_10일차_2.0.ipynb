# %% [markdown]
# ## **프로젝트: 탐색**
#
# 탐정이라는 직업을 들어보았나요?
# 현장에서 증거를 수집하고, 단서를 찾아서 사건을 해결하는 직업입니다.
# ![김도용 선생님 10일차_3.jpg](attachment:29a9084c-c5f6-4a77-93bd-a18f518b8516.jpg)

# %% [markdown]
# 훌륭한 프로그래머는 탐정이 하는 일과 비슷하합니다.
# 주어진 데이터를 살펴보고 패턴을 발견하지요.
# 그러기 위해서는 패턴을 코드로 분석하는 것이 중요합니다.
# 다음 코드를 살펴봅시다.

# %%
#예제 9-1: 카운트

seq = ['방어', '멸치', '방어', '병어', '홍합', '참치', '꽃게', '병어', '넙치', '병어', '오징어', '홍합', '한치', '홍합', '넙치', '참치', '넙치', '오징어', '멸치', '꽃게', '참치', '꽃게', '멸치', '넙치', '넙치', '오징어', '넙치', '참치', '한치', '홍합', '병어', '미역', '참치', '오징어', '오징어', '멸치', '방어', '홍합', '한치', '방어', '꽃게', '홍합', '넙치', '홍합', '홍합', '넙치', '한치', '병어', '방어', '미역', '병어', '오징어', '참치', '미역', '홍합', '한치', '멸치', '홍합', '멸치', '멸치', '병어', '홍합', '참치', '넙치', '미역', '한치', '오징어', '방어', '꽃게', '멸치', '미역', '꽃게', '참치', '오징어', '꽃게', '참치', '미역', '오징어', '홍합', '홍합', '오징어', '꽃게', '참치', '오징어', '미역', '넙치', '멸치', '오징어', '참치', '병어', '넙치', '멸치', '참치', '방어', '방어', '한치', '미역', '꽃게', '한치', '홍합']
cnt_1 = 0
cnt_2 = 0
search = '방어'

for i in seq:
    if i == search:
        cnt_1 += 1 
print(search, '의 갯수:', cnt_1)

cnt_2 = seq.count(search)
print(search, '의 갯수:', cnt_2)

# %% [markdown]
# ### **미션: 메뉴의 갯수** ###
#
# *  **미션** : seq의 값의 각 요소의 갯수를 모두 구하세요.
# 예) 오징어 는 12 개 입니다
# 미역 는 8 개 입니다
# 방어 는 8 개 입니다
# ...
#
# 힌트: set은 순서가 없고 중복을 허용하지 않는 자료형입니다.
# 얼마든지 리스트를 set으로 set을 리스트로 바꿀 수 있는데,
# 한번 리스트가 되버린 set은 어떻게 될까요?

# %%
#예제 9-2: 메뉴 갯수

seq = ['방어', '멸치', '방어', '병어', '홍합', '참치', '꽃게', '병어', '넙치', '병어', '오징어', '홍합', '한치', '홍합', '넙치', '참치', '넙치', '오징어', '멸치', '꽃게', '참치', '꽃게', '멸치', '넙치', '넙치', '오징어', '넙치', '참치', '한치', '홍합', '병어', '미역', '참치', '오징어', '오징어', '멸치', '방어', '홍합', '한치', '방어', '꽃게', '홍합', '넙치', '홍합', '홍합', '넙치', '한치', '병어', '방어', '미역', '병어', '오징어', '참치', '미역', '홍합', '한치', '멸치', '홍합', '멸치', '멸치', '병어', '홍합', '참치', '넙치', '미역', '한치', '오징어', '방어', '꽃게', '멸치', '미역', '꽃게', '참치', '오징어', '꽃게', '참치', '미역', '오징어', '홍합', '홍합', '오징어', '꽃게', '참치', '오징어', '미역', '넙치', '멸치', '오징어', '참치', '병어', '넙치', '멸치', '참치', '방어', '방어', '한치', '미역', '꽃게', '한치', '홍합']
set_tmp = set(seq)
set_tmp = list(set_tmp)

#여기서부터
for i in set_tmp:
    print(i, '는', seq.count(i), '개 입니다')
#여기까지 가리기

# %% [markdown]
# ### **미션: 연속으로 같은 메뉴** ###
#
# *  **미션** : seq의 값 중에서 연속으로 같은 값이 나온 날의 순서를 구하세요.
# 예) list = [b, a, c, d, e, e, f, g, a, c]일 때, list[4]의 e와 그 다음 e와 같으므로 [4]번째가 정답임

# %% [markdown]
# #### ** 힌트! 알고리즘을 먼저 생각해요**
# ![김도용 선생님 10일차_2.jpg](attachment:847e6ccf-3944-46e8-8321-63cf18d23983.jpg)

# %%
#예제 9-3: 연속으로 같은 메뉴

seq = ['방어', '멸치', '방어', '병어', '홍합', '참치', '꽃게', '병어', '넙치', '병어', '오징어', '홍합', '한치', '홍합', '넙치', '참치', '넙치', '오징어', '멸치', '꽃게', '참치', '꽃게', '멸치', '넙치', '넙치', '오징어', '넙치', '참치', '한치', '홍합', '병어', '미역', '참치', '오징어', '오징어', '멸치', '방어', '홍합', '한치', '방어', '꽃게', '홍합', '넙치', '홍합', '홍합', '넙치', '한치', '병어', '방어', '미역', '병어', '오징어', '참치', '미역', '홍합', '한치', '멸치', '홍합', '멸치', '멸치', '병어', '홍합', '참치', '넙치', '미역', '한치', '오징어', '방어', '꽃게', '멸치', '미역', '꽃게', '참치', '오징어', '꽃게', '참치', '미역', '오징어', '홍합', '홍합', '오징어', '꽃게', '참치', '오징어', '미역', '넙치', '멸치', '오징어', '참치', '병어', '넙치', '멸치', '참치', '방어', '방어', '한치', '미역', '꽃게', '한치', '홍합']
tmp = ''
cnt = 0
res = []

#여기서부터
for i in seq:
    if i == tmp:
        res.append(tmp+'가 ['+str(cnt)+']번째부터 연속해서 등장해')
    else:
        tmp = i
    cnt += 1
#여기까지 가리기
    
print(res)

# %% [markdown]
# ### **미션: 범인 찾기(1)** ###
#
# "seq는 사실 어떤 호텔의 메인 요리 재료를 날짜별로 나타낸 것이었다."
# "범인은 이 호텔에 5일간 연속 숙박하면서, 미역을 2번 먹었다고 한다."
# "범인이 숙박한 것으로 추정되는 가장 빠른 날짜를 구해볼까?"
#
# 예) [a, b, c, d, e, f, a, **b, c, d, c, f**]
# bcdcf동안 c가 두번 나오므로, b가 시작하는 [7]번째가 범인이 머물렀던 날이군.
#
# *  **미션** : 리스트를 5개씩 묶어서 검사하여, 미역이 2번 나오는 날을 구하세요.

# %%
#예제 9-4: 범인 찾기(1)

seq = ['방어', '멸치', '방어', '병어', '홍합', '참치', '꽃게', '병어', '넙치', '병어', '오징어', '홍합', '한치', '홍합', '넙치', '참치', '넙치', '오징어', '멸치', '꽃게', '참치', '꽃게', '멸치', '넙치', '넙치', '오징어', '넙치', '참치', '한치', '홍합', '병어', '미역', '참치', '오징어', '오징어', '멸치', '방어', '홍합', '한치', '방어', '꽃게', '홍합', '넙치', '홍합', '홍합', '넙치', '한치', '병어', '방어', '미역', '병어', '오징어', '참치', '미역', '홍합', '한치', '멸치', '홍합', '멸치', '멸치', '병어', '홍합', '참치', '넙치', '미역', '한치', '오징어', '방어', '꽃게', '멸치', '미역', '꽃게', '참치', '오징어', '꽃게', '참치', '미역', '오징어', '홍합', '홍합', '오징어', '꽃게', '참치', '오징어', '미역', '넙치', '멸치', '오징어', '참치', '병어', '넙치', '멸치', '참치', '방어', '방어', '한치', '미역', '꽃게', '한치', '홍합']

for i in range(len(seq)):
#여기서부터
    if seq[i:i+5].count("미역") == 2:
        print('['+str(i)+']번째가 범인이 머물렀던 날이군.')        
#여기까지 가리기

# %% [markdown]
# ### **미션: 범인 찾기(2)** ###
#
# "자네가 만든 프로그램이 아주 반응이 좋아."
# "이번엔 범인이 아니라 범인들일세."
# "메뉴와 횟수 그리고 머무른 기간을 알려줄 때마다 빠르게 구할 수 있는가?"
#
# *  **미션** : 메뉴, 횟수, 기간을 입력받으면 자동으로 구하는 프로그램을 완성해보세요.

# %%
#예제 9-5: 범인 찾기(2)

seq = ['방어', '멸치', '방어', '병어', '홍합', '참치', '꽃게', '병어', '넙치', '병어', '오징어', '홍합', '한치', '홍합', '넙치', '참치', '넙치', '오징어', '멸치', '꽃게', '참치', '꽃게', '멸치', '넙치', '넙치', '오징어', '넙치', '참치', '한치', '홍합', '병어', '미역', '참치', '오징어', '오징어', '멸치', '방어', '홍합', '한치', '방어', '꽃게', '홍합', '넙치', '홍합', '홍합', '넙치', '한치', '병어', '방어', '미역', '병어', '오징어', '참치', '미역', '홍합', '한치', '멸치', '홍합', '멸치', '멸치', '병어', '홍합', '참치', '넙치', '미역', '한치', '오징어', '방어', '꽃게', '멸치', '미역', '꽃게', '참치', '오징어', '꽃게', '참치', '미역', '오징어', '홍합', '홍합', '오징어', '꽃게', '참치', '오징어', '미역', '넙치', '멸치', '오징어', '참치', '병어', '넙치', '멸치', '참치', '방어', '방어', '한치', '미역', '꽃게', '한치', '홍합']

days = int(input('범인이 머무른 기간: '))
menu = input('범인이 먹은 메뉴: ')
cnt = int(input('그 메뉴를 먹은 횟수: '))

#여기서부터
for i in range(len(seq)):
    if seq[i:i+days].count(menu) == cnt:
        print('['+str(i)+']번째 날부터 범인이 머물렀을 가능성이 있겠군')        
#여기까지 가리기

# %% [markdown]
# ### **미션: 범인 찾기(3)** ###
#
# "아무리해도 범인이 안 나오네요."
# "그래서 다른 단서를 가져왔지."
# "이건 숫자잖아요? 메뉴가 아닌걸요. 그리고 리스트도 아닌데요?"
# "아닐세, 다음과 같은 규칙으로 메뉴를 숫자로 변경한 것이야."
# > '오징어'(1), '미역'(2), '방어'(3), '병어'(4), '꽃게'(5), '멸치'(6), '홍합'(7), '넙치'(8), '한치'(9), '참치'(0)
#
# "그렇다면?"
# "이번에는 정말 확실하지. 범인이 4일간 먹은 메뉴는 다음과 같다더군, 범인이 머무른 날을 찾아주게"
#
# > 조건1: 5일간 머물면서 1A3BC 메뉴를 먹었다더군
# > 조건2: A에 들어갈 숫자는 홀수야
# > 조건3: B에 들어갈 숫자는 짝수야
# > 조건4: C는 아무 숫자나 들어가도 돼
#
# *  **미션** : 조건에 맞는 5일간의 메뉴를 찾아, 범인이 처음 머무른 날의 인덱스를 모두 구하세요.
#
# ![김도용 선생님 10일차_1.jpg](attachment:0f7b01e7-7702-4e4f-afd3-8f67d1c8144e.jpg)

# %%
#예제 9-6: 범인 찾기(3)

seq = "..."
test = ""

#여기까지
for i in range(len(seq)-4):
    test = seq[i:i+5]
    if test[0] == '1':
        if test[2] == '3':
            if int(test[1])%2 == 1:
                if int(test[3])%2 == 0:
                    print(i)
#숨기기

# %% [markdown]
# ### **미션: 주소 찾기(1)** ###
#
# "범인이 숨어있을 것으로 예상되는 주소는 산천단수이예요."
# "그게 무슨 뜻이야?
# "주소가 이렇게 주어지면 산천단수는 물단흙천과 오카개미 사이에 있는 곳이라는 걸 알 수 있어요."
#
# > ... 물단흙천 **산천단수** 오카개미 ...
#
# "근데 이거 자네가 가져온 자료가 좀 이상해."
# "그러게요. 숫자 0, 1, 2, 3, 7이 있고, 한 칸 띄어쓰기, 두 칸 띄어쓰기도 있군요."
#
# *  **미션** : seq에서 한글만 남기고 공백과 숫자를 모두 지워보세요"

# %% [markdown]
# #### **힌트** ####
# 문자열에 일부를 바꾸고 싶다면 이러 방법을 이용하면 돼
# > 문자열.replace(바꾸고 싶은 문자열, 바꾸고 싶은 문자)
#
# a = "안녕"
# a = a.replace("녕", "경")
# print(a)
# 를 실행하면 "안경"이 출력되지.

# %%
#예제 9-7: 주소 탐색(1)

seq = "흙찬 흙산 천산 물오카산 단산  카개천산 오미천산 단물단카개찬 오카 물오카찬 단단카개단물오미천산  산 0물카개카개찬 흙천산 오미흙 오카천산 단천산 천산 단오미산 흙0 산 카개물07오미찬 7찬 찬  산 천산 물단0오미카개흙오카찬  산천0오단수카물카개오카물0카개천산 천산  카개오카물카개0단찬 카개물산  단찬 물흙흙오미0오카오미천산 카개물흙찬 카개0카개오카산 흙 단물카2개물단0오카오카찬 오미 0천산 단카개찬 찬 오카0천산 산  산 0산 카3개물물단흙오미물 산 단산